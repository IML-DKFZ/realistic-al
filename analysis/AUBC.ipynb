# %%
# %matplotlib notebook
# %matplotlib inline
from ipynb_setup import *
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd

import os
import re
from pathlib import Path
from IPython.display import Markdown, display

from dataframe import get_experiments_matching, create_experiment_df
from utils.pandas import filter_dataframe

# %%
savepath = Path("./plots/aubc.csv")
df = pd.read_csv(savepath)

# %%
df
# Out:
#      Unnamed: 0                                          Rel. Path  Accuracy  \
# 0             0  cifar10/active-cifar10_low/basic-pretrained_mo...  0.810394
# 1             1  cifar10/active-cifar10_low/basic-pretrained_mo...  0.816217
# 2             2  cifar10/active-cifar10_low/basic-pretrained_mo...  0.808583
# 3             3  cifar10/active-cifar10_low/basic-pretrained_mo...  0.819489
# 4             4  cifar10/active-cifar10_low/basic-pretrained_mo...  0.823806
# ..          ...                                                ...       ...
# 633        2066  isic2019/active-isic19_low_qs-160/basic-pretra...       NaN
# 634        2067  isic2019/active-isic19_low_qs-160/basic-pretra...       NaN
# 635        2068  isic2019/active-isic19_low_qs-160/basic-pretra...       NaN
# 636        2069  isic2019/active-isic19_low_qs-160/basic-pretra...       NaN
# 637        2070  isic2019/active-isic19_low_qs-160/basic-pretra...       NaN
#
#      Balanced Accuracy                                    Experiment Name  \
# 0                  NaN  basic-pretrained_model-resnet_drop-0_aug-cifar...
# 1                  NaN  basic-pretrained_model-resnet_drop-0_aug-cifar...
# 2                  NaN  basic-pretrained_model-resnet_drop-0_aug-cifar...
# 3                  NaN  basic-pretrained_model-resnet_drop-0_aug-cifar...
# 4                  NaN  basic-pretrained_model-resnet_drop-0_aug-cifar...
# ..                 ...                                                ...
# 633           0.371024  basic-pretrained_model-resnet_drop-0_aug-isic_...
# 634           0.380543  basic-pretrained_model-resnet_drop-0_aug-isic_...
# 635           0.412799  basic-pretrained_model-resnet_drop-0_aug-isic_...
# 636           0.387426  basic-pretrained_model-resnet_drop-0_aug-isic_...
# 637           0.379313  basic-pretrained_model-resnet_drop-0_aug-isic_...
#
#       Dataset              Label Regime   Query Method  Self-SL  Semi-SL  \
# 0     cifar10        active-cifar10_low         random     True    False
# 1     cifar10        active-cifar10_low         random     True    False
# 2     cifar10        active-cifar10_low         random     True    False
# 3     cifar10        active-cifar10_low  kcentergreedy     True    False
# 4     cifar10        active-cifar10_low  kcentergreedy     True    False
# ..        ...                       ...            ...      ...      ...
# 633  isic2019  active-isic19_low_qs-160        entropy     True    False
# 634  isic2019  active-isic19_low_qs-160        entropy     True    False
# 635  isic2019  active-isic19_low_qs-160         random     True    False
# 636  isic2019  active-isic19_low_qs-160         random     True    False
# 637  isic2019  active-isic19_low_qs-160         random     True    False
#
#                 Training
# 0    Self-SL Pre-Trained
# 1    Self-SL Pre-Trained
# 2    Self-SL Pre-Trained
# 3    Self-SL Pre-Trained
# 4    Self-SL Pre-Trained
# ..                   ...
# 633  Self-SL Pre-Trained
# 634  Self-SL Pre-Trained
# 635  Self-SL Pre-Trained
# 636  Self-SL Pre-Trained
# 637  Self-SL Pre-Trained
#
# [638 rows x 11 columns]

# %%
# filter_dict = {"Dataset": "cifar10", "Label Regime": "active-cifar10_low"}
filter_dict = {"Dataset": "cifar10"}

df_query = filter_dataframe(df, filter_dict)

df_query["Training"].unique()
# Out:
# array(['Self-SL Pre-Trained', 'Standard Training', 'Semi-SL'],
#       dtype=object)

# %%
df_query.groupby(["Training", "Query Method", "Label Regime"])["Accuracy"].agg(["mean", "std"]).unstack("Label Regime")
# Out:
#                                                  mean                     \
# Label Regime                      active-cifar10_high active-cifar10_low
# Training            Query Method
# Self-SL Pre-Trained badge                    0.908550           0.828207
#                     bald                     0.909326           0.800476
#                     batchbald                     NaN           0.822459
#                     entropy                  0.907113           0.800246
#                     kcentergreedy            0.901485           0.822443
#                     random                   0.898863           0.811731
# Semi-SL             badge                         NaN           0.934919
#                     entropy                       NaN           0.919270
#                     kcentergreedy                 NaN           0.934346
#                     random                        NaN           0.932589
# Standard Training   badge                    0.859930           0.472952
#                     bald                     0.857796           0.474381
#                     entropy                  0.849815           0.430743
#                     kcentergreedy            0.862867           0.468093
#                     random                   0.852604           0.471978
#
#                                                                      std  \
# Label Regime                      active-cifar10_med active-cifar10_high
# Training            Query Method
# Self-SL Pre-Trained badge                   0.872831            0.001197
#                     bald                    0.869244            0.001009
#                     batchbald                    NaN                 NaN
#                     entropy                 0.866317            0.001008
#                     kcentergreedy           0.867031            0.000926
#                     random                  0.866926            0.000704
# Semi-SL             badge                   0.948783                 NaN
#                     entropy                 0.949693                 NaN
#                     kcentergreedy           0.944150                 NaN
#                     random                  0.947833                 NaN
# Standard Training   badge                   0.728885            0.001598
#                     bald                    0.725319            0.001687
#                     entropy                 0.685906            0.002478
#                     kcentergreedy           0.728209            0.001651
#                     random                  0.730937            0.003014
#
#
# Label Regime                      active-cifar10_low active-cifar10_med
# Training            Query Method
# Self-SL Pre-Trained badge                   0.001558           0.001823
#                     bald                    0.005581           0.001064
#                     batchbald               0.004401                NaN
#                     entropy                 0.008999           0.001709
#                     kcentergreedy           0.002561           0.000887
#                     random                  0.003988           0.000858
# Semi-SL             badge                   0.001009           0.002208
#                     entropy                 0.008236           0.000712
#                     kcentergreedy           0.001832           0.000719
#                     random                  0.005048           0.000198
# Standard Training   badge                   0.010460           0.002525
#                     bald                    0.010598           0.005115
#                     entropy                 0.001832           0.004196
#                     kcentergreedy           0.003759           0.004304
#                     random                  0.014383           0.006778

# %%
df_query.groupby(["Training", "Query Method", "Label Regime"])["Accuracy"].agg(["mean", "std"]).unstack("Label Regime").swaplevel(axis=1)
# Out:
# Label Regime                      active-cifar10_high active-cifar10_low  \
#                                                  mean               mean
# Training            Query Method
# Self-SL Pre-Trained badge                    0.908550           0.828207
#                     bald                     0.909326           0.800476
#                     batchbald                     NaN           0.822459
#                     entropy                  0.907113           0.800246
#                     kcentergreedy            0.901485           0.822443
#                     random                   0.898863           0.811731
# Semi-SL             badge                         NaN           0.934919
#                     entropy                       NaN           0.919270
#                     kcentergreedy                 NaN           0.934346
#                     random                        NaN           0.932589
# Standard Training   badge                    0.859930           0.472952
#                     bald                     0.857796           0.474381
#                     entropy                  0.849815           0.430743
#                     kcentergreedy            0.862867           0.468093
#                     random                   0.852604           0.471978
#
# Label Regime                      active-cifar10_med active-cifar10_high  \
#                                                 mean                 std
# Training            Query Method
# Self-SL Pre-Trained badge                   0.872831            0.001197
#                     bald                    0.869244            0.001009
#                     batchbald                    NaN                 NaN
#                     entropy                 0.866317            0.001008
#                     kcentergreedy           0.867031            0.000926
#                     random                  0.866926            0.000704
# Semi-SL             badge                   0.948783                 NaN
#                     entropy                 0.949693                 NaN
#                     kcentergreedy           0.944150                 NaN
#                     random                  0.947833                 NaN
# Standard Training   badge                   0.728885            0.001598
#                     bald                    0.725319            0.001687
#                     entropy                 0.685906            0.002478
#                     kcentergreedy           0.728209            0.001651
#                     random                  0.730937            0.003014
#
# Label Regime                      active-cifar10_low active-cifar10_med
#                                                  std                std
# Training            Query Method
# Self-SL Pre-Trained badge                   0.001558           0.001823
#                     bald                    0.005581           0.001064
#                     batchbald               0.004401                NaN
#                     entropy                 0.008999           0.001709
#                     kcentergreedy           0.002561           0.000887
#                     random                  0.003988           0.000858
# Semi-SL             badge                   0.001009           0.002208
#                     entropy                 0.008236           0.000712
#                     kcentergreedy           0.001832           0.000719
#                     random                  0.005048           0.000198
# Standard Training   badge                   0.010460           0.002525
#                     bald                    0.010598           0.005115
#                     entropy                 0.001832           0.004196
#                     kcentergreedy           0.003759           0.004304
#                     random                  0.014383           0.006778

# %% [markdown]
# # Main Results Table

# %%
key = "Dataset"

def sorter(string : str):
    if re.match(".*_low", string):
        return 0
    elif re.match(".*_med", string):
        return 1
    elif re.match(".*_high", string):
        return 2

aubc_dict = {}
filter = get_experiments_matching(df, "Rel. Path", [".*batchbald.*"])
df_use = df[~filter]
filter = get_experiments_matching(df_use, "Rel. Path", [".*_qs-.*"])
df_use = df_use[~filter]
for dataset in df_use[key].unique():
    filter_dict = {key: dataset}

    df_query = filter_dataframe(df_use, filter_dict)
    display(Markdown(f"## {dataset}"))
    perf_metric = "Accuracy"
    if dataset in ["miotcd", "isic2019"]:
        perf_metric = "Balanced Accuracy"
    aubc_dict[dataset] = df_query.groupby(["Training", "Query Method", "Label Regime"])[perf_metric].agg(["mean", "std"]).unstack("Label Regime").swaplevel(axis=1).round(4)
    columns = list(aubc_dict[dataset].columns)
    columns.sort(key=lambda x: sorter(x[0]))
    aubc_dict[dataset] = aubc_dict[dataset][columns]
    display(aubc_dict[dataset])
# Out:
# ## cifar10
# Label Regime                      active-cifar10_low          \
#                                                 mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                     0.8282  0.0016
#                     bald                      0.8005  0.0056
#                     entropy                   0.8002  0.0090
#                     kcentergreedy             0.8224  0.0026
#                     random                    0.8117  0.0040
# Semi-SL             badge                     0.9349  0.0010
#                     entropy                   0.9193  0.0082
#                     kcentergreedy             0.9343  0.0018
#                     random                    0.9326  0.0050
# Standard Training   badge                     0.4730  0.0105
#                     bald                      0.4744  0.0106
#                     entropy                   0.4307  0.0018
#                     kcentergreedy             0.4681  0.0038
#                     random                    0.4720  0.0144
#
# Label Regime                      active-cifar10_med          \
#                                                 mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                     0.8728  0.0018
#                     bald                      0.8692  0.0011
#                     entropy                   0.8663  0.0017
#                     kcentergreedy             0.8670  0.0009
#                     random                    0.8669  0.0009
# Semi-SL             badge                     0.9488  0.0022
#                     entropy                   0.9497  0.0007
#                     kcentergreedy             0.9442  0.0007
#                     random                    0.9478  0.0002
# Standard Training   badge                     0.7289  0.0025
#                     bald                      0.7253  0.0051
#                     entropy                   0.6859  0.0042
#                     kcentergreedy             0.7282  0.0043
#                     random                    0.7309  0.0068
#
# Label Regime                      active-cifar10_high
#                                                  mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                      0.9086  0.0012
#                     bald                       0.9093  0.0010
#                     entropy                    0.9071  0.0010
#                     kcentergreedy              0.9015  0.0009
#                     random                     0.8989  0.0007
# Semi-SL             badge                         NaN     NaN
#                     entropy                       NaN     NaN
#                     kcentergreedy                 NaN     NaN
#                     random                        NaN     NaN
# Standard Training   badge                      0.8599  0.0016
#                     bald                       0.8578  0.0017
#                     entropy                    0.8498  0.0025
#                     kcentergreedy              0.8629  0.0017
#                     random                     0.8526  0.0030
# ## cifar100
# Label Regime                      active-cifar100_low          \
#                                                  mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                      0.5397  0.0030
#                     bald                       0.5028  0.0043
#                     entropy                    0.5111  0.0066
#                     kcentergreedy              0.5337  0.0044
#                     random                     0.5365  0.0017
# Semi-SL             badge                      0.5562  0.0033
#                     entropy                    0.5328  0.0158
#                     kcentergreedy              0.5220  0.0101
#                     random                     0.5713  0.0066
# Standard Training   badge                      0.3525  0.0042
#                     bald                       0.3586  0.0007
#                     entropy                    0.3036  0.0095
#                     kcentergreedy              0.3458  0.0010
#                     random                     0.3599  0.0027
#
# Label Regime                      active-cifar100_med          \
#                                                  mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                      0.6020  0.0019
#                     bald                       0.5754  0.0027
#                     entropy                    0.5857  0.0028
#                     kcentergreedy              0.5917  0.0032
#                     random                     0.5970  0.0017
# Semi-SL             badge                      0.6222  0.0041
#                     entropy                    0.6152  0.0038
#                     kcentergreedy              0.6083  0.0061
#                     random                     0.6307  0.0016
# Standard Training   badge                      0.4855  0.0044
#                     bald                       0.4865  0.0019
#                     entropy                    0.4440  0.0007
#                     kcentergreedy              0.4767  0.0031
#                     random                     0.4791  0.0044
#
# Label Regime                      active-cifar100_high
#                                                   mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                       0.6858  0.0021
#                     bald                        0.6784  0.0009
#                     entropy                     0.6857  0.0032
#                     kcentergreedy               0.6804  0.0013
#                     random                      0.6757  0.0013
# Semi-SL             badge                          NaN     NaN
#                     entropy                        NaN     NaN
#                     kcentergreedy                  NaN     NaN
#                     random                         NaN     NaN
# Standard Training   badge                       0.6627  0.0017
#                     bald                        0.6658  0.0002
#                     entropy                     0.6569  0.0021
#                     kcentergreedy               0.6560  0.0004
#                     random                      0.6474  0.0015
# ## cifar10_imb
# Label Regime                      active-cifar10_low          \
#                                                 mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                     0.5373  0.0233
#                     bald                      0.5431  0.0202
#                     entropy                   0.5282  0.0225
#                     kcentergreedy             0.5298  0.0182
#                     random                    0.5397  0.0208
# Semi-SL             badge                     0.7233  0.0166
#                     entropy                   0.6934  0.0289
#                     kcentergreedy             0.6825  0.0103
#                     random                    0.6965  0.0264
# Standard Training   badge                     0.3788  0.0152
#                     bald                      0.3919  0.0111
#                     entropy                   0.3740  0.0064
#                     kcentergreedy             0.3939  0.0249
#                     random                    0.3615  0.0118
#
# Label Regime                      active-cifar10_med          \
#                                                 mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                     0.6501  0.0026
#                     bald                      0.6549  0.0097
#                     entropy                   0.6450  0.0090
#                     kcentergreedy             0.6171  0.0154
#                     random                    0.6173  0.0097
# Semi-SL             badge                     0.7616  0.0087
#                     entropy                   0.7590  0.0101
#                     kcentergreedy             0.7608  0.0108
#                     random                    0.7363  0.0077
# Standard Training   badge                     0.5887  0.0098
#                     bald                      0.5935  0.0141
#                     entropy                   0.5793  0.0114
#                     kcentergreedy             0.6162  0.0200
#                     random                    0.5446  0.0214
#
# Label Regime                      active-cifar10_high
#                                                  mean     std
# Training            Query Method
# Self-SL Pre-Trained badge                      0.7704  0.0093
#                     bald                       0.7742  0.0036
#                     entropy                    0.7707  0.0061
#                     kcentergreedy              0.7555  0.0032
#                     random                     0.7554  0.0069
# Semi-SL             badge                         NaN     NaN
#                     entropy                       NaN     NaN
#                     kcentergreedy                 NaN     NaN
#                     random                        NaN     NaN
# Standard Training   badge                      0.7577  0.0004
#                     bald                       0.7590  0.0034
#                     entropy                    0.7431     NaN
#                     kcentergreedy              0.7667  0.0058
#                     random                     0.7263  0.0044
# ## miotcd
# Label Regime                      active-miotcd_low         active-miotcd_med  \
#                                                mean     std              mean
# Training            Query Method
# Self-SL Pre-Trained badge                    0.5446  0.0122            0.6365
#                     bald                     0.4494  0.0102            0.5741
#                     entropy                  0.5105  0.0092            0.6416
#                     kcentergreedy            0.5060  0.0082            0.5900
#                     random                   0.5298  0.0109            0.6124
# Standard Training   badge                    0.3539  0.0041            0.4688
#                     bald                     0.3254  0.0155            0.4830
#                     entropy                  0.3201  0.0097            0.4134
#                     kcentergreedy            0.3514  0.0134            0.4678
#                     random                   0.3510  0.0151            0.4564
#
# Label Regime                              active-miotcd_high
#                                       std               mean     std
# Training            Query Method
# Self-SL Pre-Trained badge          0.0054             0.7174  0.0040
#                     bald           0.0138             0.6041  0.0092
#                     entropy        0.0075             0.6972  0.0029
#                     kcentergreedy  0.0190             0.6699  0.0166
#                     random         0.0032             0.6975  0.0054
# Standard Training   badge          0.0153             0.6614  0.0080
#                     bald           0.0092             0.6884  0.0104
#                     entropy        0.0230             0.6078  0.0176
#                     kcentergreedy  0.0181             0.7098  0.0056
#                     random         0.0140             0.6065  0.0120
# ## isic2019
# Label Regime                      active-isic19_low         active-isic19_med  \
#                                                mean     std              mean
# Training            Query Method
# Self-SL Pre-Trained badge                    0.3809  0.0168            0.4679
#                     bald                     0.3949  0.0209            0.4847
#                     entropy                  0.3666  0.0165            0.4659
#                     kcentergreedy            0.3752  0.0205            0.4472
#                     random                   0.3736  0.0092            0.4555
# Standard Training   badge                    0.3204  0.0099            0.4331
#                     bald                     0.3190  0.0133            0.4521
#                     entropy                  0.3241  0.0067            0.4207
#                     kcentergreedy            0.3426  0.0099            0.4501
#                     random                   0.3376  0.0243            0.4116
#
# Label Regime                              active-isic19_high
#                                       std               mean     std
# Training            Query Method
# Self-SL Pre-Trained badge          0.0174             0.5761  0.0063
#                     bald           0.0018             0.5914  0.0080
#                     entropy        0.0104             0.5872  0.0096
#                     kcentergreedy  0.0071             0.5556  0.0069
#                     random         0.0053             0.5547  0.0066
# Standard Training   badge          0.0146             0.5628  0.0101
#                     bald           0.0211             0.5534  0.0052
#                     entropy        0.0335             0.5631  0.0061
#                     kcentergreedy  0.0139             0.5708  0.0096
#                     random         0.0201             0.5273  0.0048

# %%
for dataset in aubc_dict:
    print("-"*8)
    print("Dataset: {}".format(dataset))
    print(aubc_dict[dataset].to_latex())
# Out:
# --------
# Dataset: cifar10
# \begin{tabular}{llrrrrrr}
# \toprule
#                   & Label Regime & \multicolumn{2}{l}{active-cifar10\_low} & \multicolumn{2}{l}{active-cifar10\_med} & \multicolumn{2}{l}{active-cifar10\_high} \\
#                   & {} &               mean &     std &               mean &     std &                mean &     std \\
# Training & Query Method &                    &         &                    &         &                     &         \\
# \midrule
# Self-SL Pre-Trained & badge &             0.8282 &  0.0016 &             0.8728 &  0.0018 &              0.9086 &  0.0012 \\
#                   & bald &             0.8005 &  0.0056 &             0.8692 &  0.0011 &              0.9093 &  0.0010 \\
#                   & entropy &             0.8002 &  0.0090 &             0.8663 &  0.0017 &              0.9071 &  0.0010 \\
#                   & kcentergreedy &             0.8224 &  0.0026 &             0.8670 &  0.0009 &              0.9015 &  0.0009 \\
#                   & random &             0.8117 &  0.0040 &             0.8669 &  0.0009 &              0.8989 &  0.0007 \\
# Semi-SL & badge &             0.9349 &  0.0010 &             0.9488 &  0.0022 &                 NaN &     NaN \\
#                   & entropy &             0.9193 &  0.0082 &             0.9497 &  0.0007 &                 NaN &     NaN \\
#                   & kcentergreedy &             0.9343 &  0.0018 &             0.9442 &  0.0007 &                 NaN &     NaN \\
#                   & random &             0.9326 &  0.0050 &             0.9478 &  0.0002 &                 NaN &     NaN \\
# Standard Training & badge &             0.4730 &  0.0105 &             0.7289 &  0.0025 &              0.8599 &  0.0016 \\
#                   & bald &             0.4744 &  0.0106 &             0.7253 &  0.0051 &              0.8578 &  0.0017 \\
#                   & entropy &             0.4307 &  0.0018 &             0.6859 &  0.0042 &              0.8498 &  0.0025 \\
#                   & kcentergreedy &             0.4681 &  0.0038 &             0.7282 &  0.0043 &              0.8629 &  0.0017 \\
#                   & random &             0.4720 &  0.0144 &             0.7309 &  0.0068 &              0.8526 &  0.0030 \\
# \bottomrule
# \end{tabular}
#
# --------
# Dataset: cifar100
# \begin{tabular}{llrrrrrr}
# \toprule
#                   & Label Regime & \multicolumn{2}{l}{active-cifar100\_low} & \multicolumn{2}{l}{active-cifar100\_med} & \multicolumn{2}{l}{active-cifar100\_high} \\
#                   & {} &                mean &     std &                mean &     std &                 mean &     std \\
# Training & Query Method &                     &         &                     &         &                      &         \\
# \midrule
# Self-SL Pre-Trained & badge &              0.5397 &  0.0030 &              0.6020 &  0.0019 &               0.6858 &  0.0021 \\
#                   & bald &              0.5028 &  0.0043 &              0.5754 &  0.0027 &               0.6784 &  0.0009 \\
#                   & entropy &              0.5111 &  0.0066 &              0.5857 &  0.0028 &               0.6857 &  0.0032 \\
#                   & kcentergreedy &              0.5337 &  0.0044 &              0.5917 &  0.0032 &               0.6804 &  0.0013 \\
#                   & random &              0.5365 &  0.0017 &              0.5970 &  0.0017 &               0.6757 &  0.0013 \\
# Semi-SL & badge &              0.5562 &  0.0033 &              0.6222 &  0.0041 &                  NaN &     NaN \\
#                   & entropy &              0.5328 &  0.0158 &              0.6152 &  0.0038 &                  NaN &     NaN \\
#                   & kcentergreedy &              0.5220 &  0.0101 &              0.6083 &  0.0061 &                  NaN &     NaN \\
#                   & random &              0.5713 &  0.0066 &              0.6307 &  0.0016 &                  NaN &     NaN \\
# Standard Training & badge &              0.3525 &  0.0042 &              0.4855 &  0.0044 &               0.6627 &  0.0017 \\
#                   & bald &              0.3586 &  0.0007 &              0.4865 &  0.0019 &               0.6658 &  0.0002 \\
#                   & entropy &              0.3036 &  0.0095 &              0.4440 &  0.0007 &               0.6569 &  0.0021 \\
#                   & kcentergreedy &              0.3458 &  0.0010 &              0.4767 &  0.0031 &               0.6560 &  0.0004 \\
#                   & random &              0.3599 &  0.0027 &              0.4791 &  0.0044 &               0.6474 &  0.0015 \\
# \bottomrule
# \end{tabular}
#
# --------
# Dataset: cifar10_imb
# \begin{tabular}{llrrrrrr}
# \toprule
#                   & Label Regime & \multicolumn{2}{l}{active-cifar10\_low} & \multicolumn{2}{l}{active-cifar10\_med} & \multicolumn{2}{l}{active-cifar10\_high} \\
#                   & {} &               mean &     std &               mean &     std &                mean &     std \\
# Training & Query Method &                    &         &                    &         &                     &         \\
# \midrule
# Self-SL Pre-Trained & badge &             0.5373 &  0.0233 &             0.6501 &  0.0026 &              0.7704 &  0.0093 \\
#                   & bald &             0.5431 &  0.0202 &             0.6549 &  0.0097 &              0.7742 &  0.0036 \\
#                   & entropy &             0.5282 &  0.0225 &             0.6450 &  0.0090 &              0.7707 &  0.0061 \\
#                   & kcentergreedy &             0.5298 &  0.0182 &             0.6171 &  0.0154 &              0.7555 &  0.0032 \\
#                   & random &             0.5397 &  0.0208 &             0.6173 &  0.0097 &              0.7554 &  0.0069 \\
# Semi-SL & badge &             0.7233 &  0.0166 &             0.7616 &  0.0087 &                 NaN &     NaN \\
#                   & entropy &             0.6934 &  0.0289 &             0.7590 &  0.0101 &                 NaN &     NaN \\
#                   & kcentergreedy &             0.6825 &  0.0103 &             0.7608 &  0.0108 &                 NaN &     NaN \\
#                   & random &             0.6965 &  0.0264 &             0.7363 &  0.0077 &                 NaN &     NaN \\
# Standard Training & badge &             0.3788 &  0.0152 &             0.5887 &  0.0098 &              0.7577 &  0.0004 \\
#                   & bald &             0.3919 &  0.0111 &             0.5935 &  0.0141 &              0.7590 &  0.0034 \\
#                   & entropy &             0.3740 &  0.0064 &             0.5793 &  0.0114 &              0.7431 &     NaN \\
#                   & kcentergreedy &             0.3939 &  0.0249 &             0.6162 &  0.0200 &              0.7667 &  0.0058 \\
#                   & random &             0.3615 &  0.0118 &             0.5446 &  0.0214 &              0.7263 &  0.0044 \\
# \bottomrule
# \end{tabular}
#
# --------
# Dataset: miotcd
# \begin{tabular}{llrrrrrr}
# \toprule
#                   & Label Regime & \multicolumn{2}{l}{active-miotcd\_low} & \multicolumn{2}{l}{active-miotcd\_med} & \multicolumn{2}{l}{active-miotcd\_high} \\
#                   & {} &              mean &     std &              mean &     std &               mean &     std \\
# Training & Query Method &                   &         &                   &         &                    &         \\
# \midrule
# Self-SL Pre-Trained & badge &            0.5446 &  0.0122 &            0.6365 &  0.0054 &             0.7174 &  0.0040 \\
#                   & bald &            0.4494 &  0.0102 &            0.5741 &  0.0138 &             0.6041 &  0.0092 \\
#                   & entropy &            0.5105 &  0.0092 &            0.6416 &  0.0075 &             0.6972 &  0.0029 \\
#                   & kcentergreedy &            0.5060 &  0.0082 &            0.5900 &  0.0190 &             0.6699 &  0.0166 \\
#                   & random &            0.5298 &  0.0109 &            0.6124 &  0.0032 &             0.6975 &  0.0054 \\
# Standard Training & badge &            0.3539 &  0.0041 &            0.4688 &  0.0153 &             0.6614 &  0.0080 \\
#                   & bald &            0.3254 &  0.0155 &            0.4830 &  0.0092 &             0.6884 &  0.0104 \\
#                   & entropy &            0.3201 &  0.0097 &            0.4134 &  0.0230 &             0.6078 &  0.0176 \\
#                   & kcentergreedy &            0.3514 &  0.0134 &            0.4678 &  0.0181 &             0.7098 &  0.0056 \\
#                   & random &            0.3510 &  0.0151 &            0.4564 &  0.0140 &             0.6065 &  0.0120 \\
# \bottomrule
# \end{tabular}
#
# --------
# Dataset: isic2019
# \begin{tabular}{llrrrrrr}
# \toprule
#                   & Label Regime & \multicolumn{2}{l}{active-isic19\_low} & \multicolumn{2}{l}{active-isic19\_med} & \multicolumn{2}{l}{active-isic19\_high} \\
#                   & {} &              mean &     std &              mean &     std &               mean &     std \\
# Training & Query Method &                   &         &                   &         &                    &         \\
# \midrule
# Self-SL Pre-Trained & badge &            0.3809 &  0.0168 &            0.4679 &  0.0174 &             0.5761 &  0.0063 \\
#                   & bald &            0.3949 &  0.0209 &            0.4847 &  0.0018 &             0.5914 &  0.0080 \\
#                   & entropy &            0.3666 &  0.0165 &            0.4659 &  0.0104 &             0.5872 &  0.0096 \\
#                   & kcentergreedy &            0.3752 &  0.0205 &            0.4472 &  0.0071 &             0.5556 &  0.0069 \\
#                   & random &            0.3736 &  0.0092 &            0.4555 &  0.0053 &             0.5547 &  0.0066 \\
# Standard Training & badge &            0.3204 &  0.0099 &            0.4331 &  0.0146 &             0.5628 &  0.0101 \\
#                   & bald &            0.3190 &  0.0133 &            0.4521 &  0.0211 &             0.5534 &  0.0052 \\
#                   & entropy &            0.3241 &  0.0067 &            0.4207 &  0.0335 &             0.5631 &  0.0061 \\
#                   & kcentergreedy &            0.3426 &  0.0099 &            0.4501 &  0.0139 &             0.5708 &  0.0096 \\
#                   & random &            0.3376 &  0.0243 &            0.4116 &  0.0201 &             0.5273 &  0.0048 \\
# \bottomrule
# \end{tabular}
